# %%
import h5py
Data = h5py.File('../data/COMPAS/Z_0.02/COMPAS_Output.h5', 'r')
for items in Data['Run_Details']:
    print(items,'\t\t\t',Data['Run_Details'][items][1])
# Out:
# Actual-Random-Seed 			 1646093638
# Actual-Random-Seed-Derivation 			 b'CALCULATED   '
# COMPAS-Version 			 b'02.27.05'
# COMPAS-Version-Derivation 			 b'CALCULATED   '
# Clock-Time 			 5785.85
# Clock-Time-Derivation 			 b'CALCULATED   '
# Objects-Created 			 200000
# Objects-Created-Derivation 			 b'CALCULATED   '
# Objects-Requested 			 200000
# Objects-Requested-Derivation 			 b'CALCULATED   '
# PISN-lower-limit 			 60.0
# PISN-lower-limit-Derivation 			 b'USER_SUPPLIED'
# PISN-upper-limit 			 135.0
# PISN-upper-limit-Derivation 			 b'USER_SUPPLIED'
# PPI-lower-limit 			 35.0
# PPI-lower-limit-Derivation 			 b'USER_SUPPLIED'
# PPI-upper-limit 			 60.0
# PPI-upper-limit-Derivation 			 b'USER_SUPPLIED'
# Run-End 			 b'Tue Mar  1 12:50:41 2022\n'
# Run-End-Derivation 			 b'CALCULATED   '
# Run-Start 			 b'Tue Mar  1 11:13:58 2022\n'
# Run-Start-Derivation 			 b'CALCULATED   '
# Wall-Time 			 b'0001:36:42'
# Wall-Time-Derivation 			 b'CALCULATED   '
# ...

# %%
for keys in Data:
    print(Data[keys])
# Out:
# <HDF5 group "/BSE_Common_Envelopes" (73 members)>
# <HDF5 group "/BSE_Double_Compact_Objects" (12 members)>
# <HDF5 group "/BSE_Supernovae" (32 members)>
# <HDF5 group "/BSE_System_Parameters" (147 members)>
# <HDF5 group "/Run_Details" (370 members)>
